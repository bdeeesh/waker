# %%
from waker.scopeClass import scopeData
# Out:
# New version, updated June
# Adding H data analysis
# add ed number of channel

# %%
import matplotlib.pyplot as plt

# %%
#Hor example
M = scopeData('GR_H_10turns001',num_of_chan=2,plan='H')
# Out:
# 20000
# processing time is 162.7170250415802
# 0.44205 is the highest tune peak at nan intensity

# %%
#vert example
MV = scopeData('./../0707/10turnsInstab000',num_of_chan=2,plan='V')
# Out:
# 20000
# processing time is 58.4573438167572
# 0.43955 is the highest tune peak at nan intensity

# %%
plt.plot(M.CH1V[100])
